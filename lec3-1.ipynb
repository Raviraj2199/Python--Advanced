# %%
# !pip install yfinance
# Out:
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.8 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/60.8 kB 435.7 kB/s eta 0:00:01
#      ------------------- ------------------ 30.7/60.8 kB 435.7 kB/s eta 0:00:01
#      ------------------------------- ------ 51.2/60.8 kB 290.5 kB/s eta 0:00:01
#      -------------------------------------- 60.8/60.8 kB 324.4 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/948.2 kB ? eta -:--:--
#      -- ------------------------------------ 71.7/948.2 kB 2.0 MB/s eta 0:00:01
#      ---- --------------------------------- 102.4/948.2 kB 1.2 MB/s eta 0:00:01
#      ------ ------------------------------- 174.1/948.2 kB 1.5 MB/s eta 0:00:01
#      -------- ----------------------------- 204.8/948.2 kB 1.6 MB/s eta 0:00:01
#      --------- ---------------------------- 225.3/948.2 kB 1.1 MB/s eta 0:00:01
# ...

# %%
import yfinance as yf

# %%
txn = yf.Ticker("TXN")

txn_history_data = txn.history("1mo")

close = txn_history_data["Close"]

print(txn_history_data)
print(type(txn_history_data))
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-12-30 00:00:00-05:00  189.690002  189.690002  187.210007  187.960007
# 2024-12-31 00:00:00-05:00  188.660004  189.100006  186.059998  187.509995
# 2025-01-02 00:00:00-05:00  189.320007  190.130005  184.970001  186.949997
# 2025-01-03 00:00:00-05:00  188.929993  191.139999  187.199997  190.509995
# 2025-01-06 00:00:00-05:00  190.250000  193.770004  189.240005  192.179993
# 2025-01-07 00:00:00-05:00  193.820007  195.009995  191.089996  192.210007
# 2025-01-08 00:00:00-05:00  191.800003  192.690002  188.070007  191.660004
# 2025-01-10 00:00:00-05:00  192.910004  192.910004  188.419998  190.149994
# 2025-01-13 00:00:00-05:00  189.830002  191.759995  187.649994  191.089996
# 2025-01-14 00:00:00-05:00  191.539993  193.610001  190.179993  193.500000
# 2025-01-15 00:00:00-05:00  195.669998  198.949997  195.669998  197.509995
# 2025-01-16 00:00:00-05:00  195.169998  195.479996  187.139999  187.369995
# ...

# %%
# !pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/103.0 kB ? eta -:--:--
#      ----------- ------------------------- 30.7/103.0 kB 660.6 kB/s eta 0:00:01
#      -------------------------------------  102.4/103.0 kB 1.2 MB/s eta 0:00:01
#      ------------------------------------ 103.0/103.0 kB 986.7 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.0 MB 16.5 MB/s eta 0:00:01
#    ------- -------------------------------- 1.4/8.0 MB 15.1 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.3/8.0 MB 18.4 MB/s eta 0:00:01
#    ------------- -------------------------- 2.7/8.0 MB 15.6 MB/s eta 0:00:01
#    ------------------ --------------------- 3.6/8.0 MB 16.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.8/8.0 MB 17.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.7/8.0 MB 18.2 MB/s eta 0:00:01
# ...

# %%
txn_history_data["Close"].plot()
# Out:
# Open            1.915400e+02
# High            1.929100e+02
# Low             1.880700e+02
# Close           1.910900e+02
# Volume          5.407500e+06
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# dtype: float64

# %%
# !pip install seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/294.9 kB 435.7 kB/s eta 0:00:01
#    --------- ----------------------------- 71.7/294.9 kB 558.5 kB/s eta 0:00:01
#    ---------------------- --------------- 174.1/294.9 kB 952.6 kB/s eta 0:00:01
#    ------------------------------- -------- 235.5/294.9 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 1.1 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 24.0 -> 25.0
# [notice] To update, run: C:\Users\Raviraj\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

sns.lineplot

#set theme as dark
#sns.set_style("dark") 

# Removing the spines 
#sns.despine() 

#dark grid
#sns.axes_style('darkgrid')

txn_history_data["Close"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a histogram
sns.histplot(data=txn_history_data["Close"])
plt.show()

# %%
close.min()
close.max()
close.mean()
close.median()
close.std()
# Out:
# np.float64(4.755871582401509)

# %%
import pandas as pd
import numpy as np
data = pd.Series([1, np.nan, 2, None, 3], index = list('abcde'))
data.fillna(0)
 
#fwd fill
data.fillna(method='ffill')
#backward fill
data.fillna(method='bfill')
# Out:
# C:\Users\Raviraj\AppData\Local\Temp\ipykernel_16716\4275142774.py:6: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='ffill')
# C:\Users\Raviraj\AppData\Local\Temp\ipykernel_16716\4275142774.py:8: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='bfill')
# a    1.0
# b    2.0
# c    2.0
# d    3.0
# e    3.0
# dtype: float64
